# %%
import logging

# Get logger
logger = logging.getLogger("my logger")

# Create a handler
c_handler = logging.StreamHandler()

# link handler to logger
logger.addHandler(c_handler)

# Set logging level to the logger
logger.setLevel(logging.DEBUG) # <-- THIS!

# test
logger.debug('This is a debug message') # WILL WORK

# %%
from playwright.async_api import async_playwright
import logging

from src.presentations_module.sources.sokratic_source import SokraticSource

apw = await async_playwright().start()
logger = logging.getLogger("sokratic_source")

source = SokraticSource(apw, logger)
await source.init_async()

await source.authenticate(login="artiv09@gmail.com", password="Barck1994")

async for response in source.generate_presentation(
    topic="Влияние климата на экосистемы",
    language="kz",
    slides_amount=10,
    audience="Средняя школа",
    author="Кривощеков Артем",
):
    print(response)
# Out:
# {'stage': 'start', 'step': 1, 'total_steps': 8, 'percent': 12}
# {'stage': 'form_saved', 'step': 2, 'total_steps': 8, 'percent': 25}
# {'stage': 'style_selected', 'step': 3, 'total_steps': 8, 'percent': 37}
# {'stage': 'generation_started', 'step': 4, 'total_steps': 8, 'percent': 50}
# {'stage': 'downloaded_powerpoint', 'step': 5, 'total_steps': 8, 'percent': 62, 'files': ['./assets/presentations/aa5b851bb6024eeebdb170427770afdb/77645943-905e-4418-bdb2-a4f4dd4936ee.pptx']}
# {'stage': 'downloaded_pdf', 'step': 6, 'total_steps': 8, 'percent': 75, 'files': ['./assets/presentations/aa5b851bb6024eeebdb170427770afdb/77645943-905e-4418-bdb2-a4f4dd4936ee.pptx', './assets/presentations/aa5b851bb6024eeebdb170427770afdb/8c4757c2-548c-4266-ac67-1f9286c3ea4d.pdf']}
# {'stage': 'downloaded_text', 'step': 7, 'total_steps': 8, 'percent': 87, 'files': ['./assets/presentations/aa5b851bb6024eeebdb170427770afdb/77645943-905e-4418-bdb2-a4f4dd4936ee.pptx', './assets/presentations/aa5b851bb6024eeebdb170427770afdb/8c4757c2-548c-4266-ac67-1f9286c3ea4d.pdf', './assets/presentations/aa5b851bb6024eeebdb170427770afdb/presentation_text.txt']}
# {'stage': 'done', 'step': 8, 'total_steps': 8, 'percent': 100, 'files': ['./assets/presentations/aa5b851bb6024eeebdb170427770afdb/77645943-905e-4418-bdb2-a4f4dd4936ee.pptx', './assets/presentations/aa5b851bb6024eeebdb170427770afdb/8c4757c2-548c-4266-ac67-1f9286c3ea4d.pdf', './assets/presentations/aa5b851bb6024eeebdb170427770afdb/presentation_text.txt']}
